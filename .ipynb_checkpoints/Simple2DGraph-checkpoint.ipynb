# %%
#importing package into your code
import numpy as np #essential
import matplotlib.pyplot as plt # for graphing

# %%
#Data
x = np.array([0,1,2,3,4,5])
y = np.array([10,20,5,10,30,20])

# %%
# matplotlib.pyplot.plot function
plt.plot(x,y)

# %%
# matplotlib.pyplot.scatter function
plt.scatter(x,y)

# %%
#add title, y and x axis
